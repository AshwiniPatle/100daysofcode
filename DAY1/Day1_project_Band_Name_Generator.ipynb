# %% [markdown]
# # Band Name Generator
#
# generate a band name using the city and pet name provided by the user. To achieve this, we will cover four topics in the Python programming language: comments, input()function, print() function, string manipulation, and variables.

# %%
from IPython.display import Image, display

display(Image(filename="project_output_SS.PNG"))

# %%
print("Welcome to a simple band name generator.")
city = input("Where the city did you grow up in? ")
petname = input("What is your pet's name? ")
print("Your band name could be " + city + " " + petname)
# Out:
# Welcome to a simple band name generator.
# Where the city did you grow up in?  Gonsia
# What is your pet's name?  Jwnny
# Your band name could be Gonsia Jwnny
