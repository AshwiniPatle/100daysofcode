# %% [markdown]
# # Treasure Island, Choose Your Own Adventure

# %%
from IPython.display import Image, display

display(Image(filename="flowchart_SS.PNG"))

# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
''')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\`'
# <>:1: SyntaxWarning: invalid escape sequence '\`'
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# ...

# %%
print('''Welcome to Tresure Island.
Your mission is to find the tresure.''')
# Out:
# Welcome to Tresure Island.
# Your mission is to find the tresure.

# %%
direction = input("which direction would you like to go? left or right ?")
if direction == "left":
    swim_wait = input("do yo uwant to swin or wait?")
    if swim_wait == "wait":
        colour = input("which colour will you choose? ")
        if colour == "red":
            print("game over!! you are burned by fire.")
        elif colour == "yellow":
            print("congratulations!! you won the game. ")
        elif colour == "blue":
            print("game over!! you are eaten by the beast. ")
        else:
            print("game over!!")
    else:
        print("game over!! you get attached by thout. ")
else:
    print("game over!! you fall into a hole. ")
# Out:
# which direction would you like to go? left or right ? left
# do yo uwant to swin or wait? wait
# which colour will you choose?  yellow
# congratulations!! you won the game.
